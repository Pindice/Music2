# %% [markdown]
# # Afficher matrice de correlation

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', None)    # Afficher toutes les lignes
pd.set_option('display.max_columns', None) # Afficher toutes les colonnes
pd.set_option('display.width', None)       # Ajuster la largeur de l'affichage

# %%
# TODO: Essayer dataframe ne contenant que les 'genres' choisie selon la répartition des classes 
df = pd.read_csv('./csv/filtered_with_label.csv').drop(columns=['track_id'])
# Out:
# ['Rock' 'Reggae' 'Country' 'Pop' 'New' 'Ambient' 'Hip-Hop'
#  'Electronica/Dance' 'Jazz' 'R&B' 'Bubblegum' 'MPB' 'Latin' 'Folk' 'Other'
#  'PunkNotProfit' 'Lo-Fi' 'Gospel' 'Soundtrack' 'Electronic' 'Dance'
#  'House' 'Grandes' 'Trance' "Children's" 'Christmas' 'Books'
#  'Instrumental' 'Juke' 'World' 'Hardcore' 'Classical:' 'Dubstep'
#  'Pakistani' 'Meditative' 'Infantil' 'Pop/Rap' 'Jump' 'Proto'
#  'Regionalista' 'Comedy' 'jazz/bossa' 'Easy' 'Techno' 'gospel'
#  'Soundtracks' 'Rap/West' 'Flamenco' 'Latinas' 'Drum' 'zouk' 'Cabaret'
#  'Classical' 'Data' 'Pop:' 'Musique' 'Southern' 'Oi!' 'Bhangra'
#  'Ghettotech' 'Bachata' 'Orchestral' 'Military' 'CH-Rock' 'Tango'
#  'Nouvelle' 'Sub-noize' 'Jug' 'EPIC' 'Doo' 'Hit' 'Samba' 'Danzon' 'Greek'
#  'Gabber' 'Lasten' 'Primus' 'GAITAS' 'Unclassifiable' 'Grupo,' 'Lebanese'
#  'Early' 'Son' 'Soukous' 'Blues/Zydeco' 'Irish' 'iTunes' 'Chill' 'Lounge'
#  'Western' 'Finnish' 'Remix' 'Hip' 'Space' 'Crunk'
# ...

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['genre'] = label_encoder.fit_transform(df['genre'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9,9))

# plt.matshow(df.corr())
sns.heatmap(df.corr(), annot=True, cmap='inferno')
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                            duration  end_of_fade_in       key  key_confidence  \
# duration                   1.000000        0.121618  0.014449        0.020594
# end_of_fade_in             0.121618        1.000000 -0.013881        0.004715
# key                        0.014449       -0.013881  1.000000       -0.034772
# key_confidence             0.020594        0.004715 -0.034772        1.000000
# loudness                   0.095695       -0.095349  0.051685       -0.015451
# mode                      -0.063143       -0.004450 -0.162446        0.149421
# mode_confidence           -0.003976        0.016097 -0.036395        0.772101
# start_of_fade_out          0.998166        0.117433  0.013267        0.017269
# tempo                     -0.010577       -0.007485  0.016658        0.046815
# time_signature             0.113430        0.022889  0.006156       -0.110222
# time_signature_confidence  0.118593        0.018964  0.014337       -0.034046
# ...
