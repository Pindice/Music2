# %% [markdown]
# # Save csv filtered_with_data

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 4)    # Afficher toutes les lignes
pd.set_option('display.max_columns', None) # Afficher toutes les colonnes
pd.set_option('display.width', None)       # Ajuster la largeur de l'affichage

# %%
labels = []

for file in ['msd_beatunes_map.cls']:
    
    file_path = f'./{file}'

    with open(file_path, 'r') as cls_file:
        for _ in range(7):  # Ignorer les 7 premières lignes
            next(cls_file)

        for line in cls_file:
            parts = line.strip().split()
            track_id = parts[0]
            genres = parts[1:]  # Prendre tous les éléments après le premier comme genres

            labels.append({'track_id': track_id, 'genre': genres[0]})

labels_df = pd.DataFrame(labels)

# %%
labels_df
# Out:
#                   track_id       genre
# 0       TRAAAAK128F9318786        Rock
# 1       TRAAAAV128F421A322        Rock
# ...                    ...         ...
# 677036  TRZZZZL128F92F9D4A       House
# 677037  TRZZZZZ12903D05E3A  Electronic
#
# [677038 rows x 2 columns]

# %%
df = pd.read_csv('filtered_without_label.csv')

merged_df = pd.merge(df, labels_df, how='left', on='track_id')

# %%
# Display track with genre !
genres = list(merged_df['genre'].unique())[1:]

merged_df = merged_df.loc[merged_df['genre'].isin(genres)]

# %%
merged_df
# Out:
#                 track_id   duration  end_of_fade_in  key  key_confidence  \
# 1     TRBBTUV128F933D382  179.59138           0.000    2           0.277
# 2     TRBBTSI128E0790E7B  184.99873           0.245   11           0.424
# ...                  ...        ...             ...  ...             ...
# 9997  TRANNZZ128F92C22F7  254.19710           0.136   11           0.617
# 9999  TRANNLE128E07871BF  243.14730           0.362   10           0.146
#
#       loudness  mode  mode_confidence  start_of_fade_out    tempo  \
# 1      -10.223     1            0.313            175.723   70.183
# 2      -15.726     1            0.583            174.817  141.257
# ...        ...   ...              ...                ...      ...
# 9997    -3.773     0            0.619            246.404  127.952
# 9999   -21.361     0            0.504            219.220   93.394
#
#       time_signature  time_signature_confidence    genre
# 1                  4                      0.293     Rock
# 2                  4                      0.517   Reggae
# ...              ...                        ...      ...
# 9997               1                      0.000  Hip-Hop
# 9999               4                      0.000     Jazz
#
# [6546 rows x 13 columns]

# %%
merged_df.to_csv('filtered_with_label.csv', index=False)
