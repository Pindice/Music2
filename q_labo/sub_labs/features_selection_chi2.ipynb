# %%
from sklearn.feature_selection import chi2
import pandas as pd

df = pd.read_csv('../csv/balanced_data_label_encoded.csv')

# %%
X = df.drop(columns=['track_id', 'genre'])
X

# chi2(X=X, y=df['genre'])
# Out:
#        duration  end_of_fade_in  key  key_confidence  loudness  mode  \
# 0     185.78240           0.352   11           0.698   -10.316     1
# 1     208.14322           0.259    0           0.717    -5.384     1
# 2     227.57832           2.682    0           0.463    -7.695     0
# 3     138.42240           0.125    9           0.609    -4.994     0
# 4     197.06730           0.293    9           0.000   -20.832     1
# ...         ...             ...  ...             ...       ...   ...
# 1849  399.88200           3.663    3           1.000   -10.648     1
# 1850  368.11710           0.496    9           0.850   -12.157     1
# 1851  175.25506           0.000    4           0.582   -11.951     1
# 1852  262.97424           0.165    5           0.312    -8.737     1
# 1853  164.54485           0.000    6           0.195   -10.897     1
#
#       mode_confidence  start_of_fade_out    tempo  time_signature  \
# 0               0.650            175.177  101.040               4
# ...
